# %% [markdown]
# <a href="https://colab.research.google.com/github/muntasha2900/GraphCOS231/blob/main/Gholiyana_Muntasha_1101172010_GraphCOS231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
  #frek = frekuensi (MHz)
  #tipe = urban, suburban, open
  #ht = tinggi tower (meter)
  #hr = tinggi user (meter)
  #d = jarak (meter)
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800
loc='urban'
tower=80
user=1.5
dmin=200
dmax=700
N=200
d=np.random.randint(dmin,dmax,N)

# %%
LpUrban=cos(f,loc,tower,user,d)
print("Value of Lp= ",LpUrban)
# Out:
# Value of Lp=  [181.82525143 183.78752308 176.82220984 180.84280631 185.32573025
#  182.11872533 175.53874529 184.01782092 182.34918016 179.33392003
#  184.68695008 182.5759253  172.38390337 184.66272611 184.0684909
#  184.63846041 182.68794368 181.7061282  181.06364771 176.03943972
#  177.28000084 180.05821908 185.713554   184.49198175 185.82561694
#  186.56487928 175.63111439 185.37191467 180.68291541 174.43053827
#  172.15010153 182.34918016 174.17763673 183.07313824 186.30837014
#  170.39488001 185.46383172 184.807449   185.60059238 186.39439323
#  171.04713715 178.97547226 187.26727123 185.91462979 186.06906151
#  172.61388787 173.00754089 175.90464216 186.98227982 182.74362058
#  183.4744827  178.19166482 170.65941807 187.10512569 183.52714159
#  180.39045706 187.0233476  175.39904592 179.04789523 174.97143758
#  184.9744343  179.92309826 172.84017768 177.23899284 181.52553294
#  182.66002249 177.92039464 185.41794817 184.11897926 177.15661694
# ...

# %%
d_sort= d[np.argsort(d)]
LpUrban_sort= LpUrban[np.argsort(d)]

# %%
f=1800
loc2='suburban'
tower=80
user=1.5
dmin=200
dmax=700
N=200
d2=np.random.randint(dmin,dmax,N)

# %%
LpSuburban=cos(f,loc2,tower,user,d2)
print("Value of Lp= ",LpSuburban)
# Out:
# Value of Lp=  [166.62562223 169.43999878 177.98825129 181.2399069  177.95799083
#  182.89102544 179.14826754 180.82593408 183.22843649 175.04012237
#  181.61871931 174.11610347 174.85255319 179.06450373 176.28750656
#  181.59533965 168.81636127 182.65427638 178.28733339 167.98049183
#  172.56105131 178.92378091 170.8127778  176.08136282 178.31689528
#  169.60539682 182.23573345 167.28706944 181.45424093 175.62409149
#  175.65979807 173.71245873 172.78149772 182.95490872 179.20383462
#  176.59117374 183.37354986 179.42393656 182.10093589 183.65936738
#  175.90724148 183.14483839 174.50850315 181.85040607 181.33556932
#  182.52344351 172.10953069 176.25335809 177.95799083 177.4961056
#  173.33901672 175.97714851 172.29187935 182.6759642  169.21640301
#  167.98049183 181.0709183  181.14359037 166.42097595 183.5986071
#  177.40188292 180.626832   179.09248038 177.65175622 180.11640523
#  175.37157855 182.56718963 174.54714854 169.93047826 180.7516002
# ...

# %%
d_sort2= d2[np.argsort(d2)]
LpSuburban_sort= LpSuburban[np.argsort(d2)]

# %%
f=1800
loc3='open'
tower=80
user=1.5
dmin=200
dmax=700
N=200
d3=np.random.randint(dmin,dmax,N)

# %%
LpOpen=cos(f,loc3,tower,user,d3)
print("Value of Lp= ",LpOpen)
# Out:
# Value of Lp=  [176.75415581 174.8683511  168.74341104 183.58529912 171.60819912
#  167.02422189 178.53718576 180.77253012 168.19333621 176.51452995
#  172.23010347 179.79521082 172.55393929 173.9463052  175.17542021
#  183.26826614 172.08900476 166.61191233 181.07547164 181.05047387
#  181.56633097 173.9876745  175.51305591 182.04065988 177.25431146
#  181.37203496 170.8547448  179.49108004 168.86278665 183.68941073
#  182.63433311 177.83196022 167.02422189 178.47724423 169.15687327
#  181.80549185 172.87049728 180.59275801 180.97521329 174.90710281
#  173.90481404 180.06610836 172.08900476 178.833126   179.40698285
#  176.95635408 175.36399381 177.44950494 182.6789805  180.72140035
#  182.87816078 175.66055713 171.51003679 172.46217195 183.97689495
#  172.69047901 171.05963914 177.25431146 180.79802558 172.69047901
#  184.09832878 179.06548158 177.67386387 181.71031421 183.1394277
#  178.56706114 180.09291376 170.16747496 169.61500267 176.65195775
# ...

# %%
d_sort3= d3[np.argsort(d3)]
LpOpen_sort= LpOpen[np.argsort(d3)]

# %%
plt.figure()
plt.plot(d_sort,LpUrban_sort,'r',label='Urban')
plt.plot(d_sort2,LpSuburban_sort,'g',label='Suburban')
plt.plot(d_sort3,LpOpen_sort,'y',label='Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
f2=900
loc='urban'
tower=80
user=1.5
dmin=200
dmax=700
N=200
d4=np.random.randint(dmin,dmax,N)

# %%
LpUrban2=cos(f2,loc,tower,user,d4)

# %%
d_sort4= d4[np.argsort(d4)]
LpUrban2_sort= LpUrban2[np.argsort(d4)]

# %%
f3=700
loc='urban'
tower=80
user=1.5
dmin=200
dmax=700
N=200
d5=np.random.randint(dmin,dmax,N)

# %%
LpUrban3=cos(f3,loc,tower,user,d5)

# %%
d_sort5= d5[np.argsort(d5)]
LpUrban3_sort= LpUrban3[np.argsort(d5)]

# %%
plt.figure()
plt.plot(d_sort,LpUrban_sort,'r',label='1800 MHz')
plt.plot(d_sort4,LpUrban2_sort,'g',label='900 MHz')
plt.plot(d_sort5,LpUrban3_sort,'b',label='700 MHz')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
